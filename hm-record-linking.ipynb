# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

#import numpy as np # linear algebra
#import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install textblob
# !pip install Distance
# !pip install zipfile36
import datetime
import seaborn as sns
import spacy
from nltk import trigrams
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
#from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from sklearn import metrics
#from textblob_de import TextBlobDE as TextBlob
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
import en_core_web_lg
nlp = spacy.blank("en")
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np 
import re
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('wordnet') 
nltk.download('omw-1.4')
stopnow = set(stopwords.words("english"))
from nltk.tokenize import word_tokenize
import gensim
from textblob import TextBlob
from textblob import Word
from sklearn.preprocessing import LabelEncoder
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)
from string import punctuation
from spacy.matcher import Matcher
from spacy import displacy
from gensim.models import Word2Vec
#import en_core_web_sm
#nlp = en_core_web_sm.load()
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import OrdinalEncoder
import scipy

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import time 
#import turicreate as tc 
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
from sklearn.decomposition import LatentDirichletAllocation
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk import ngrams
import pandas as pd
from collections import Counter
from itertools import chain
import warnings
warnings.filterwarnings('ignore')
nltk.download('averaged_perceptron_tagger')
from numpy import array

# !pip install dedupe
# !pip install fuzzymatcher
# !pip install values
# !pip install similarity
# !pip install jarowinkler
# !pip install strsim
# !pip install pyjarowinkler
# !pip install Levenshtein
# !pip install strsimpy
# !pip install weighted-levenshtein
# !pip install recordlinkage
# !pip install keras-visualizer
# !pip install tfidf-matcher
# !pip install textdistance
# !pip install Distance
# !python3 -m pip install tabulate
# !pip install textblob

from textblob import TextBlob
from nltk.tokenize import TabTokenizer
from textblob import Word
import tabulate
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec
import string
import values
from similarity.jarowinkler import JaroWinkler
#from similarity.levenshtein import Levenshtein
from similarity.normalized_levenshtein import NormalizedLevenshtein
from similarity.weighted_levenshtein import WeightedLevenshtein
from similarity.weighted_levenshtein import CharacterSubstitutionInterface
from similarity.damerau import Damerau
from similarity.optimal_string_alignment import OptimalStringAlignment
from similarity.longest_common_subsequence import LongestCommonSubsequence
from similarity.metric_lcs import MetricLCS
from similarity.ngram import NGram
from similarity.qgram import QGram
from similarity.cosine import Cosine
from sklearn.metrics.pairwise import euclidean_distances
from keras_visualizer import visualizer
import sklearn
import tfidf_matcher
from strsimpy.jaro_winkler import JaroWinkler
from strsimpy.damerau import Damerau
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from sklearn.metrics.pairwise import cosine_similarity
import textdistance
import distance
from gensim.models import Word2Vec
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from difflib import SequenceMatcher
import sys, types, os
import numpy as np
import pandas as pd
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.util import ngrams
from gensim.models import Word2Vec
import collections
from collections import Counter
from matplotlib import pyplot as plt
stop = stopwords.words('english')
pd.options.mode.chained_assignment = None
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from spacy.matcher import Matcher
import spacy
from spacy import displacy
from gensim.models import Word2Vec
import en_core_web_sm
nlp = en_core_web_sm.load()
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline 
import nltk
import gzip
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
import heapq
from wordcloud import WordCloud
import PIL
import itertools
import matplotlib.pyplot as plt
from nltk import corpus
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
vect=CountVectorizer()
import scipy
import math
import os
import sklearn
from itertools import islice

from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import RegexpParser
from nltk import Tree
NP = "NP: {(<V\w+>|<NN\w?>)+.*<NN\w?>}"
chunker = RegexpParser(NP)
from nltk import trigrams
import textdistance

w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)


nltk.download('punkt')
nltk.download('wordnet')
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)
# %matplotlib inline


def get_continuous_chunks(text, chunk_func=ne_chunk):
    chunked = chunk_func(pos_tag(word_tokenize(text)))
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
articles = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/articles.csv')   
customer = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/customers.csv')  
train = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/transactions_train.csv')
sample = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/sample_submission.csv')

# %%
cust_sample = sample[['customer_id']]
train_sample = pd.merge(cust_sample, train,on= 'customer_id', how='left')
train_sam_cust = pd.merge(train_sample, customer, on='customer_id', how='left')
train_sam_cust = train_sam_cust[['t_dat','customer_id','article_id','price','Active','club_member_status','fashion_news_frequency']]
train_sam_cust = train_sam_cust.sample(900000)
train_sam_cust_art = pd.merge(train_sam_cust, articles, on='article_id', how='inner')

# %%
datause = train_sam_cust_art.copy()

# %%
#datause.head()

# %%
datause['Active'] = datause['Active'].fillna(0)
datause['Active'] = datause['Active'].astype(np.int64)
datause['fashion_news_frequency'] = datause['fashion_news_frequency'].fillna('NONE')
datause['club_member_status'] = datause['club_member_status'].fillna('NONE')
datause.product_code = datause.product_code.astype(str)
datause.price = datause.price.astype(str)
datause.article_id = datause.article_id.astype(str)
datause['words'] = datause['product_group_name'] +" "+ datause['graphical_appearance_name'] +" "+ datause['colour_group_name'] +" "+ datause['perceived_colour_value_name']+" "+ datause['perceived_colour_master_name'] +" "+ datause['department_name'] +" "+ datause['index_name'] +" "+ datause['index_group_name']+" "+ datause['section_name']+" "+ datause['garment_group_name']+" "+ datause['detail_desc']
datause.words = datause.words.astype(str)
datause['words'] = datause['words'].apply(lambda x: " ".join(x.lower() for x in x.split()))
datause['words'] = datause['words'].str.replace('[^\w\s]','')
datause['words'] = datause['words'].apply(lambda x: " ".join(x for x in x.split() if x not in stopnow))
datause['words'] = datause['words'].str.replace('\d+', '')
datause['words'] = datause['words'].str.split().apply(lambda x: ' '.join(list(set(x))))
datause['token_words']  = datause.apply(lambda row: nltk.word_tokenize(row['words']), axis=1)
datause.token_words = datause.token_words.astype(str)
datause['lemma_words'] = datause.token_words.apply(lemmatize_text)



#datause['words'] = datause['words'].astype(str)
datause['product_type_name'] = datause['product_type_name'].apply(lambda x: " ".join(x.lower() for x in x.split()))
datause['index_name'] = datause['index_name'].apply(lambda x: " ".join(x.lower() for x in x.split()))
datause['prod_name'] = datause['prod_name'].apply(lambda x: " ".join(x.lower() for x in x.split()))
datause['product_type_name'] = datause['product_type_name'].str.replace('[^\w\s]','')
datause['index_name'] = datause['index_name'].str.replace('[^\w\s]','')
datause['prod_name'] = datause['prod_name'].str.replace('[^\w\s]','')

datause['tag'] = datause['article_id'] +" "+ datause['product_code'] +" "+ datause['product_type_name'] +" "+ datause['index_name']+" "+ datause['prod_name']+" "+ datause['perceived_colour_value_name']+" "+ datause['product_group_name']
datause.tag = datause.tag.astype(str)
datause['tag'] = datause['tag'].apply(lambda x: " ".join(x.lower() for x in x.split()))
datause['tag'] = datause['tag'].str.replace('[^\w\s]','')
datause['token_tag']  = datause.apply(lambda row: nltk.word_tokenize(row['tag']), axis=1)
datause.token_tag = datause.token_tag.astype(str)
datause['lemma_tag'] = datause.token_tag.apply(lemmatize_text)

##datause['tag'] = datause['product_code'] +" - "+ datause['product_type_name'] 
##datause['tag'] = datause['product_type_name'] 
##datause['tag'] = datause['tag'].apply(lambda x: " ".join(x.lower() for x in x.split()))
##datause = datause.dropna()
##datause = datause.reset_index(drop=True)
##datause['words_token'] = datause.words.apply(lambda x: word_tokenize(x))
##datause['words_lemma'] = datause['words'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
dataset = datause[['t_dat',
 'customer_id',
 'article_id',
 'price',
 'Active',
 'club_member_status',
 'fashion_news_frequency','token_words','lemma_words','token_tag','lemma_tag']]

# %%
dataset.head()

# %%
#%%time
#tokens = []
#lemma = []
#pos = []
#ep = []



#for doc in nlp.pipe(dataset['words'].astype('unicode').values, batch_size=100,
#                       n_process=10):
 #   if doc.is_parsed:
  #      tokens.append([n.text for n in doc])
  #      lemma.append([n.lemma_ for n in doc])
  #      #pos.append([n.pos_ for n in doc])
        #dep.append([n.dep_ for n in doc])
        
        
        
 #   else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
   #     tokens.append(None)
   #     lemma.append(None)
        #pos.append(None)
        #dep.append(None)
        
        
        

#dataset['tokens_words'] = tokens
#dataset['lemma_words'] = lemma
#dataset['pos_words'] = pos
#dataset['dep_words'] = dep

# %%
#%%time
#tokens = []
#lemma = []
#pos = []
#dep = []



#for doc in nlp.pipe(dataset['tag'].astype('unicode').values, batch_size=100,
 #                       n_process=10):
  #  if doc.is_parsed:
  #     tokens.append([n.text for n in doc])
  #      lemma.append([n.lemma_ for n in doc])
 #       #pos.append([n.pos_ for n in doc])
        #dep.append([n.dep_ for n in doc])
        
        
        
 #   else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
   #     tokens.append(None)
   #     lemma.append(None)
        #pos.append(None)
        #dep.append(None)
        
        
        

#dataset['tokens_tag'] = tokens
#dataset['lemma_tag'] = lemma
#dataset['pos_tag'] = pos
#dataset['dep_tag'] = dep

# %%
features = dataset[['t_dat',
 'customer_id','price','Active',
 'club_member_status',
 'fashion_news_frequency',
 'lemma_tag','lemma_words']]

# %%
target = features[['lemma_tag']] 
features = features.drop('lemma_tag',1)

# %%
target['lemma_words'] = target['lemma_tag']

# %% [markdown]
# features.to_csv (r'C:\Users\Naeemah\Desktop\org_features.csv', index = False, header=True)
# target.to_csv (r'C:\Users\Naeemah\Desktop\org_target.csv', index = False, header=True)

# %%
import fuzzymatcher

# %%
features.columns.to_list()

# %%
features['lemma_words'] = features['lemma_words'].astype(str)

# %%
#features.head()

# %% [markdown]
# left_on = ["lemma_words"]

# %%
target['lemma_words'] = target['lemma_words'].astype(str)

# %%
#target.head()

# %% [markdown]
# right_on = ["lemma_words"]

# %% [markdown]
# matched_results = fuzzymatcher.fuzzy_left_join(features,
#                                             target,
#                                             left_on,
#                                             right_on,
#                                             left_id_col='lemma_words',
#                                             right_id_col='lemma_words')

# %% [markdown]
# %%time
# from recordlinkage.standardise import value_occurence
# features["product_info"] = value_occurence(features["lemma_words"])

# %%
#features.head()

# %%
#featuresnew = features[features["product_info"] >= 15]

# %% [markdown]
# %%time
# jarowinkler = JaroWinkler()
# features["jarowinkler_sim"] = [jarowinkler.similarity(i,j) for i,j in zip(features['lemma_words'],target['lemma_words'])]

# %%
#features

# %%
#features.sample(20)

# %%
features.columns.to_list()

# %%
features.info()

# %%
features['price'] = features['price'].astype(str)
features['Active'] = features['Active'].astype(str)
#features['product_info'] = features['product_info'].astype(str)
#features['jarowinkler_sim'] = features['jarowinkler_sim'].astype(str)
target['lemma_tag'] = target['lemma_tag'].astype(str)
target['lemma_words'] = target['lemma_words'].astype(str)

# %% [markdown]
# left_on = ["t_dat",
#  "customer_id",
#  "price",
#  "Active",
#  "club_member_status",
#  "fashion_news_frequency",
#  "lemma_words",
#  "product_info",
#  "jarowinkler_sim"]

# %% [markdown]
# right_on = ["lemma_tag","lemma_words"]

# %%
features.info()

# %%
target.head()

# %% [markdown]
# %%time
# import recordlinkage
#
# indexer = recordlinkage.Index()
# # Create indexing object
# indexer = recordlinkage.SortedNeighbourhoodIndex(on='lemma_words', window=9)
#
# # Create pandas MultiIndex containing candidate links
# candidate_links = indexer.index(features, target)
# comp = recordlinkage.Compare()
# comp.string('lemma_words', 'lemma_words', method='jarowinkler', label='words')
# mymatches = comp.compute(candidate_links, features, target)
# print(mymatches)

# %% [markdown]
# mymatches

# %% [markdown]
# t =mymatches.sum(axis=1).value_counts().sort_index(ascending=False)
# print(t)

# %% [markdown]
# #potential_matches = mymatches[mymatches].reset_index()
# #potential_matches['Score'] = potential_matches.loc[:,'words']
#
# potential_matches = mymatches[mymatches.sum(axis=1) < 1].reset_index()
# potential_matches['Score'] = potential_matches.loc[:,'words']

# %% [markdown]
# potential_matches.head()

# %% [markdown]
# potential_matches.dtypes

# %% [markdown]
# from tabulate import tabulate
# print(tabulate(potential_matches,headers =["Recordid_1","Recordid_2","words", "Score" ]))

# %%
#potential_matches['level_1']

# %%
#features.head()

# %%
features.columns.to_list()

# %%
target.columns.to_list()

# %%
features['Features_Lookup'] = features[['lemma_words']].apply(lambda x: '_'.join(x), axis=1)

# %%
target['Target_Lookup'] =  target[['lemma_words']].apply(lambda x: '_'.join(x), axis=1)

# %%
#features.head()

# %%
#features.info()

# %%
#target.info()

# %%
#target.head()

# %%
#target.to_csv ('finaltarget.csv', index = False, header=True)
#features.to_csv ('finalfeatures.csv', index = False, header=True)

# %%
feat_lookup = features[['Features_Lookup','t_dat','customer_id','price','Active','club_member_status','fashion_news_frequency']].reset_index()
tar_lookup = target[['Target_Lookup','lemma_words']].reset_index()
#print(feat_lookup)

# %%
tar_lookup.info()

# %%
feat_lookup.info()

# %%
feat_lookup.head()

# %%
tar_lookup.head()

# %%
targetfinal = tar_lookup[['Target_Lookup']]

# %%
targetfinal.info()

# %%
targetfinal.head()

# %%
targetfinal['target_label'] = targetfinal['Target_Lookup'].str.replace("[\[\]\"']", "")

# %%
targetfinal['target_label'] = targetfinal['target_label'] .str.replace(',','')

# %%
targetfinal = targetfinal[['target_label']]

# %%
feat_lookup.head()

# %%
feat_lookup.columns.to_list()

# %%
feat_lookup['features_label'] = feat_lookup['Features_Lookup'].str.replace("[\[\]\"']", "")
feat_lookup['features_label'] = feat_lookup['features_label'] .str.replace(',','')

# %%
feat_lookup.columns.to_list()

# %%
featuresfinal = feat_lookup[['customer_id','features_label']]

# %%
featuresfinal.head()

# %%
targetfinal['article'] = targetfinal['target_label'].str[:9]
targetfinal['target_label'] = targetfinal['target_label'].str[15:]

# %%
targetfinal.head()

# %%
#eft_on = ["customer_id","features_label"]
#right_on = ["article","target_label"]

# %% [markdown]
# matched_results = fuzzymatcher.fuzzy_left_join(featuresfinal,
#                                             targetfinal,
#                                             left_on,
#                                             right_on,
#                                             left_id_col='features_label',
#                                             right_id_col='target_label')

# %%
def get_adjectives(text):
    blob = TextBlob(text)
    return [ word for (word,tag) in blob.tags if tag == "JJ"]

targetfinal['adjectives'] = targetfinal['target_label'].apply(get_adjectives)

# %%
def get_verbs(text):
    blob = TextBlob(text)
    return [ word for (word,tag) in blob.tags if tag == "VB"]

targetfinal['verbs'] = targetfinal['target_label'].apply(get_verbs)

# %%
def get_nouns(text):
    blob = TextBlob(text)
    return [ word for (word,tag) in blob.tags if tag == "NN"]

targetfinal['nouns'] = targetfinal['target_label'].apply(get_nouns)

# %%
targetfinal.head()

# %%
#targetfinal['label'] = targetfinal['adjectives'] +" "+ targetfinal['nouns']
targetfinal.adjectives = targetfinal.adjectives.astype(str)
targetfinal.nouns = targetfinal.nouns.astype(str)
targetfinal['label'] = targetfinal['adjectives'] +" "+ targetfinal['nouns']

# %%
targetfinal.head()

# %%
targetfinal = targetfinal[['article','label']]

# %%
targetfinal.head()

# %%
targetfinal['label'] = targetfinal['label'].str.replace("[\[\]\"']", "")

# %%
targetfinal.head()

# %%
featuresfinal.head()

# %%
featuresfinal['label'] = featuresfinal['features_label']

# %%
targetfinal.head()

# %%
featuresfinal.head()

# %%
# %%time 
import recordlinkage
indexer = recordlinkage.Index()
indexer = recordlinkage.SortedNeighbourhoodIndex(on='label', window=9)
candidate_links = indexer.index(featuresfinal, targetfinal) 
comp = recordlinkage.Compare() 
comp.string('label', 'label', method='jarowinkler', label='labels') 
mymatches = comp.compute(candidate_links, featuresfinal, targetfinal)

# %%
mymatches.head()

# %%
#print(len(candidate_links))

# %%
mymatches.sum(axis=1).value_counts().sort_index(ascending=False)

# %%
potential_matches = mymatches[mymatches.sum(axis=1) < 1].reset_index() 
potential_matches['Score'] = potential_matches.loc[:,'labels']

# %%
featuresfinal['features_labels'] = featuresfinal[['label']].apply(lambda x: '_'.join(x), axis=1)
targetfinal['target_labels'] = targetfinal[['label']].apply(lambda x: '_'.join(x), axis=1)

# %%
feat_label_lookup = featuresfinal[['features_labels','customer_id','label']].reset_index()
tar_label_lookup = targetfinal[['target_labels','article','label']].reset_index()

# %%
results_feat_merge  = pd.merge(potential_matches, feat_label_lookup, how='left', left_index=True, right_index=True)

# %%
results_target_merge  = pd.merge(potential_matches, tar_label_lookup, how='left', left_index=True, right_index=True)

# %%
final_table  = pd.merge(results_feat_merge, results_target_merge,  left_index=True, right_index=True)

# %%
final_table.head()

# %%
final_table.columns.to_list()

# %%
cols = ['level_0_x','level_1_x','index_x','index_y','Score_x','customer_id','article','features_labels','label_y']

# %%
final_table = final_table[cols].sort_values(by=['level_0_x'], ascending=False)

# %%
final_table.to_csv('final_results04072022.csv', index=False)

# %%
#final_table.to_csv(os.path.join('/input/hm-record-linking/final_results04072022.csv'),index = False)

# %%
potential_matches.head()

# %%
#featuresfinal
#targetfinal

# %%
#featuresfinal.head()

# %%
#featuresfinal['features_labels'] = featuresfinal[['label']].apply(lambda x: '_'.join(x), axis=1)

# %%
#targetfinal['target_labels'] = targetfinal[['label']].apply(lambda x: '_'.join(x), axis=1)

# %%
#feat_label_lookup = featuresfinal[['features_labels']].reset_index()
#tar_label_lookup = targetfinal[['target_labels']].reset_index()

# %%
#potential_matches.info()

# %%
#results_feat_merge  = pd.merge(potential_matches, feat_lookup, how='left', left_index=True, right_index=True)

# %%
#results_feat_merge.info()

# %%
#results_target_merge  = pd.merge(potential_matches, tar_lookup, how='left', left_index=True, right_index=True)

# %%
#results_target_merge.head()

# %%
#final_table  = pd.merge(results_feat_merge, results_target_merge,  left_index=True, right_index=True)

# %%
#final_table.head()

# %%
#final_table.info()

# %%
#final_table.columns.to_list()

# %%
#results_table = final_table[['level_0_x',
# 'level_1_x','t_dat',
#'customer_id',
# 'price',
# 'Active',
# 'club_member_status',
# 'fashion_news_frequency',
 #'product_info','jarowinkler_sim','Score_y','Features_Lookup','Target_Lookup']]

# %%
#results_table.head()

# %%
#def extract_first_value(row):
 #   return row.split()[0].strip()

# %%
#results_table['tar_article'] = results_table['Target_Lookup'].apply(extract_first_value)
#results_table['tar_article'] = results_table['Target_Lookup'].str.replace('[^\w\s]','')

# %%
#results_table.head()

# %%
#results_table['tar_article'] = results_table['tar_article'].apply(extract_first_value)

# %%
#results_table.head()

# %%
#results_table.columns.to_list()

# %%
#myresults = results_table[['level_0_x',
# 'level_1_x',
# 'customer_id',
# 'price',
# 'Active',
# 'club_member_status',
# 'fashion_news_frequency','jarowinkler_sim','Score_y','tar_article']]

# %%
#myresults['price'] = myresults['price'].astype(str)
#myresults['Active'] = myresults['Active'].astype(str)
#myresults['jarowinkler_sim'] = myresults['jarowinkler_sim'].astype(str)
#myresults['Score_y'] = myresults['Score_y'].astype(str)
#myresults['tar_article'] = myresults['tar_article'].astype(str)

# %%
#myresults['infomation'] =  myresults['price'] +","+ myresults['Active'] +","+ myresults['club_member_status']+","+ myresults['fashion_news_frequency']+","+ myresults['jarowinkler_sim']+","+ myresults['Score_y']

# %%
#myresults.to_csv ('myresults.csv', index = False, header=True)

# %%
#myresults.columns.to_list()

# %%
#myresults = myresults[['level_0_x',
# 'level_1_x','customer_id','tar_article']]

# %%
#myresults.head()

# %%
#myresults.info()
